# %% [markdown]
# ## Segunda parte do Teste Final
#
# ### Este notebook é para ser preenchido pelos alunos que escolheram a metodologia de avaliação por teste final. As suas respostas deverão ser feitas nas células de código (input) correspondentes a cada pergunta

# %% [markdown]
# No diretório deste notebook tem um ficheiro csv (atletas_federados.csv) com os atletas federados nas várias modalidades desportivas em Portugal. Tem duas colunas ("Homens" e "Mulheres") com a contagem por género de atletas federados por clube (coluna "Designação da Instituição") e variante desportiva (coluna "Variante"). Também contém duas colunas com o Distrito e o Concelho a que cada Instituição pertence.

# %% [markdown]
# **1 - Abra o ficheiro atletas_federados.csv e apresente uma listagem das colunas presentes no mesmo, utilizando o módulo Pandas de python (0,5 valores)**

# %% [markdown]
# **2 - Calcule e apresente o número total de mulheres federadas (2,5 valores)**

# %% [markdown]
# **3 - Quais são as Federações Desportivas com mais de mil (1000) atletas federados femininos? (2,5 valores)

# %% [markdown]
# **4 - Calcule e apresente o número de registos por distrito (2 valores)**

# %% [markdown]
# **5 - Construa um gráfico de barras (utilizando a biblioteca seaborn) com a contagem de registos por distrito, como apresentado na seguinte figura (as cores das barras podem ser diferentes): (2,5 valores)**
# ![imagem_dist_distrito.png](attachment:imagem_dist_distrito.png)
